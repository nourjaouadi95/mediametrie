# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib as mpl 
import matplotlib.pyplot as plt
from urllib.parse import urlparse
import nltk
import os
from nltk.tokenize import word_tokenize 
import re

# %%
cookies_ori = pd.read_pickle("./cookies.pkl")

# %%
cookies_ori = pd.read_csv('./url_decompose.csv',sep=",",header=0)
# Out:
# /home/ensai/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cookies = cookies_ori.copy()

# %%
cookies.head()
# Out:
#    COOKIE_ID               LOCAL_TIME  \
# 0          0  2018-02-28 16:24:05.570
# 1          1  2018-02-17 18:17:16.310
# 2          2  2018-02-09 22:49:13.500
# 3          3  2018-02-11 14:15:36.478
# 4          4  2018-02-26 09:41:26.059
#
#                                            PAGE_NAME  H2549  id scheme  \
# 0  http://www.01net.com/actualites/pourquoi-la-no...      1   0   http
# 1                        http://www.01net.com/search      0   1   http
# 2  http://www.01net.com/telecharger/windows/Multi...      0   2   http
# 3                  http://www.01net.com/telecharger/      0   3   http
# 4  http://www.01net.com/tests/huawei-p8-lite-2017...      0   4   http
#
#           netloc                                               path params  \
# 0  www.01net.com  /actualites/pourquoi-la-nouvelle-interface-de-...    NaN
# 1  www.01net.com                                            /search    NaN
# 2  www.01net.com  /telecharger/windows/Multimedia/lecteurs_video...    NaN
# 3  www.01net.com                                      /telecharger/    NaN
# 4  www.01net.com  /tests/huawei-p8-lite-2017-fiche-technique-365...    NaN
#
#   query  fragment                                       path_explode
# 0   NaN       NaN  [actualites, pourquoi, la, nouvelle, interface...
# 1   NaN       NaN                                           [search]
# 2   NaN       NaN  [telecharger, windows, Multimedia, lecteurs, v...
# 3   NaN       NaN                                      [telecharger]
# 4   NaN       NaN  [tests, huawei, p8, lite, 2017, fiche, techniq...

# %% [markdown]
# # 1. Exploser le path

# %%
import math
def to_bag_of_word(path):
    ret = ['no_path']
    if path != "" and path == path:
        ret = re.split('-|_|/',path)
        
    
    ret = list(filter(None, ret))
    
    
    return(ret)

# %%
cookies['path_explode'] = cookies.apply(lambda row : to_bag_of_word(row['path']), axis = 1)

# %%
cookies.to_csv('path_decompose.csv',index=False)

# %% [markdown]
# # 2. Analyse des mots du path

# %%
bag_of_words = cookies['path_explode'].tolist()

# %%
flat_list = [item for sublist in bag_of_words for item in sublist]

# %%
flat_list
# Out:
# ['actualites',
#  'pourquoi',
#  'la',
#  'nouvelle',
#  'interface',
#  'de',
#  'snapchat',
#  'est',
#  'une',
#  'bonne',
#  'idee',
#  '1380794.html',
#  'search',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'lecteurs',
#  'video',
#  'dvd',
#  'fiches',
#  '23823.html',
#  'telecharger',
#  'tests',
#  'huawei',
#  'p8',
#  'lite',
#  '2017',
#  'fiche',
#  'technique',
#  '36545.html',
#  'telecharger',
#  'windows',
#  'Securite',
#  'antivirus',
#  'antitrojan',
#  'fiches',
#  'telecharger',
#  '25899.html',
#  'recherche',
#  'recherche.php',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'reseau',
#  'fiches',
#  '105522.html',
#  'actualites',
#  'soldes',
#  'un',
#  'pc',
#  'portable',
#  'gamer',
#  'asus',
#  'de',
#  '17',
#  'pouces',
#  'a',
#  'moins',
#  'de',
#  '800',
#  'euros',
#  '1378304.html',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'lecteurs',
#  'audio',
#  'mp3',
#  'cd',
#  'fiches',
#  '110198.html',
#  'tests',
#  'comparateur',
#  'huawei',
#  'p8',
#  'lite',
#  '2017',
#  'huawei',
#  'honor',
#  '7x',
#  '36545',
#  '48283.html',
#  'telecharger',
#  'windows',
#  'Securite',
#  'antivirus',
#  'antitrojan',
#  'fiches',
#  'img127850.html',
#  '404',
#  'tests',
#  'samsung',
#  'galaxy',
#  'j5',
#  '2016',
#  'fiche',
#  'technique',
#  '27233.html',
#  'actualites',
#  'comment',
#  'fonctionne',
#  'une',
#  'batterie',
#  'lithium',
#  'ion',
#  '1378434.html',
#  'no_param',
#  'telecharger',
#  'windows',
#  'Loisirs',
#  'Bricolage',
#  'telecharger',
#  'windows',
#  'Internet',
#  'courrier',
#  'email',
#  'fiches',
#  'avis',
#  '26957.html',
#  'mediaplayer',
#  'telecharger',
#  'windows',
#  'Loisirs',
#  'education',
#  'et',
#  'scolarite',
#  'fiches',
#  '34923.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Internet',
#  'partage',
#  'fiches',
#  'tele117296.html',
#  'recherche',
#  'recherche.php',
#  'actualites',
#  'google',
#  'publie',
#  'une',
#  'faille',
#  'zero',
#  'day',
#  'dans',
#  'windows',
#  '10',
#  '1378961.html',
#  'tests',
#  'comparateur',
#  'nvidia',
#  'shield',
#  'tv',
#  '4k',
#  'hdr',
#  '16',
#  'go',
#  'google',
#  'chromecast',
#  '35345',
#  '26687.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'photo',
#  'numerique',
#  'fiches',
#  'postele38694.html',
#  'tests',
#  'huawei',
#  'p8',
#  'lite',
#  '2017',
#  'fiche',
#  'technique',
#  '36545.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Bureautique',
#  'editeur',
#  'de',
#  'texte',
#  'fiches',
#  'tele27030.html',
#  'telecharger',
#  'astuces',
#  'addiction',
#  'aux',
#  'ecrans',
#  'nos',
#  '5',
#  'conseils',
#  'pour',
#  'reprendre',
#  'le',
#  'controle',
#  'sur',
#  'votre',
#  'smartphone',
#  '1368478.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'manipulation',
#  'de',
#  'fichier',
#  'fiches',
#  'postele140474.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Loisirs',
#  'astronomie',
#  'et',
#  'espace',
#  'fiches',
#  'tele32089.html',
#  'telecharger',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'optimiseurs',
#  'et',
#  'tests',
#  'fiches',
#  '124191.html',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'photo',
#  'numerique',
#  'index3.html',
#  'telecharger',
#  'windows',
#  'Programmation',
#  'java',
#  'fiches',
#  '8138.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'nettoyeurs',
#  'et',
#  'installeurs',
#  'fiches',
#  'tele32599.html',
#  'telecharger',
#  'windows',
#  'Internet',
#  'courrier',
#  'email',
#  'fiches',
#  '26957.html',
#  '404',
#  'outils',
#  'telecharger',
#  'windows',
#  'Internet',
#  'communication',
#  'fiches',
#  'postele135629.html',
#  'telecharger',
#  'actualites',
#  'xperia',
#  'ear',
#  'duo',
#  'quand',
#  'sony',
#  'prend',
#  'les',
#  'autres',
#  'ecouteurs',
#  'true',
#  'wireless',
#  'a',
#  'contre',
#  'courant',
#  '1383491.html',
#  'telecharger',
#  'mac',
#  'Internet',
#  'fiches',
#  '33884.html',
#  'telecharger',
#  'linux',
#  'Loisirs',
#  'fiches',
#  '140879.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'albmums',
#  'et',
#  'visionneuses',
#  'fiches',
#  'postele45360.html',
#  'actualites',
#  'tests',
#  'test',
#  'cyber',
#  'shot',
#  'rx100',
#  'le',
#  'compact',
#  'expert',
#  'qui',
#  'egale',
#  'les',
#  'reflex',
#  '3214.html',
#  'actualites',
#  'bon',
#  'plan',
#  'le',
#  'smartphone',
#  'honor',
#  '6a',
#  'a',
#  'seulement',
#  '105',
#  'euros',
#  '1377151.html',
#  'tests',
#  'test',
#  'synology',
#  'ds218',
#  'un',
#  'nas',
#  'performant',
#  'pour',
#  'la',
#  'diffusion',
#  'multimedia',
#  '5836.html',
#  'actualites',
#  'operations',
#  'avast',
#  'telecharger',
#  'ff',
#  'actualites',
#  'six',
#  'mois',
#  'avec',
#  'le',
#  'samsung',
#  'galaxy',
#  's8',
#  'les',
#  'bonnes',
#  'et',
#  'les',
#  'mauvaises',
#  'surprises',
#  '1260408.html',
#  'telecharger',
#  'windows',
#  'Internet',
#  'navigateur',
#  'fiches',
#  '45352.html',
#  'telecharger',
#  'telecharger',
#  'mac',
#  'audio',
#  'et',
#  'musique',
#  'new',
#  'index.html',
#  'tests',
#  'samsung',
#  'galaxy',
#  'j5',
#  '2016',
#  'fiche',
#  'technique',
#  '27233.html',
#  'statiquesv6',
#  'telecharger',
#  'top',
#  'post',
#  'telechargement.html',
#  'no_param',
#  'telecharger',
#  'windows',
#  'Internet',
#  'plugins',
#  'fiches',
#  '48778.html',
#  'actualites',
#  'jeu',
#  'concours',
#  'tentez',
#  'de',
#  'gagner',
#  '4',
#  'disques',
#  'durs',
#  'externes',
#  'toshiba',
#  'canvio',
#  'for',
#  'desktop',
#  '1372809.html',
#  'outils',
#  'telecharger',
#  'mac',
#  'Utilitaire',
#  'fiches',
#  'tele106662.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'compression',
#  'et',
#  'decompression',
#  'fiches',
#  'postele112.html',
#  'telecharger',
#  'windows',
#  'Internet',
#  'editeur',
#  'de',
#  'site',
#  'fiches',
#  '29119.html',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'gestion',
#  'de',
#  'fichier',
#  'fiches',
#  '112114.html',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'planificateurs',
#  'et',
#  'lanceurs',
#  'fiches',
#  '40817.html',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'photo',
#  'numerique',
#  'fiches',
#  '33029.html',
#  'telecharger',
#  'windows',
#  'Jeux',
#  'patches',
#  'fiches',
#  '108654.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'encodeurs',
#  'et',
#  'decodeurs',
#  'fiches',
#  'postele125107.html',
#  'astuces',
#  'comment',
#  'installer',
#  'windows',
#  '10',
#  'sur',
#  'votre',
#  'pc',
#  'gratuitement',
#  '1358237.html',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'lecteurs',
#  'audio',
#  'mp3',
#  'cd',
#  'fiches',
#  '27133.html',
#  'forum',
#  'high',
#  'tech',
#  'INTERNET',
#  'E',
#  'mail',
#  'outlook',
#  'demande',
#  'passe',
#  'sujet',
#  '48509',
#  '1.htm',
#  'actualites',
#  'le',
#  'top',
#  '10',
#  'des',
#  'meilleurs',
#  'compacts',
#  'experts',
#  '643422.html',
#  'tests',
#  'test',
#  'p8',
#  'lite',
#  '2017',
#  'un',
#  'smartphone',
#  'beau',
#  'performant',
#  'et',
#  'd',
#  'un',
#  'rapport',
#  'qualite',
#  'prix',
#  'imbattable',
#  '5642.html',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'gestion',
#  'de',
#  'fichier',
#  'fiches',
#  '131323.html',
#  'mediaplayer',
#  'live',
#  'video',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'compression',
#  'et',
#  'decompression',
#  'fiches',
#  '19486.html',
#  'telecharger',
#  'outils',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'lecteurs',
#  'video',
#  'dvd',
#  'fiches',
#  'tele23823.html',
#  'telecharger',
#  'mac',
#  'Utilitaire',
#  'fiches',
#  '34037.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'imprimantes',
#  'fiches',
#  'tele30310.html',
#  'no_param',
#  'actualites',
#  'on',
#  'a',
#  'teste',
#  'c',
#  'evolution',
#  'le',
#  'scooter',
#  'electrique',
#  'de',
#  'bmw',
#  'a',
#  'l',
#  'acceleration',
#  'epoustouflante',
#  '1299439.html',
#  'outils',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'photo',
#  'numerique',
#  'fiches',
#  'tele33029.html',
#  'outils',
#  'telecharger',
#  'mac',
#  'Multimedia',
#  'fiches',
#  'tele23810.html',
#  'actualites',
#  'google',
#  'chrome',
#  'gare',
#  'a',
#  'cette',
#  'arnaque',
#  'qui',
#  'fait',
#  'planter',
#  'votre',
#  'navigateur',
#  '1368232.html',
#  'actualites',
#  'le',
#  'homepod',
#  'd',
#  'apple',
#  'est',
#  'robuste',
#  'mais',
#  'irreparable',
#  '1372471.html',
#  'recherche',
#  'recherche.php',
#  'forum',
#  'high',
#  'tech',
#  'LOGICIELS',
#  'liste',
#  'sujet',
#  '1.htm',
#  'telecharger',
#  'windows',
#  'Securite',
#  'antivirus',
#  'antitrojan',
#  'fiches',
#  '144165.html',
#  'astuces',
#  'comment',
#  'reparer',
#  'une',
#  'cle',
#  'usb',
#  'protegee',
#  'en',
#  'ecriture',
#  '651391.html',
#  'actualites',
#  'actualites',
#  'on',
#  'a',
#  'teste',
#  'c',
#  'evolution',
#  'le',
#  'scooter',
#  'electrique',
#  'de',
#  'bmw',
#  'a',
#  'l',
#  'acceleration',
#  'epoustouflante',
#  '1299439.html',
#  'tests',
#  'jvc',
#  'everio',
#  'gz',
#  'mg460',
#  'fiche',
#  'technique',
#  '6617.html',
#  'actualites',
#  'mauvaise',
#  'nouvelle',
#  'pour',
#  'les',
#  'decus',
#  'du',
#  'nouveau',
#  'snapchat',
#  'il',
#  'n',
#  'y',
#  'aura',
#  'pas',
#  'de',
#  'retour',
#  'en',
#  'arriere',
#  '1377514.html',
#  'astuces',
#  'comment',
#  'installer',
#  'windows',
#  '10',
#  'sur',
#  'votre',
#  'pc',
#  'gratuitement',
#  '1358237.html',
#  'tests',
#  'test',
#  'dell',
#  'xps',
#  '13',
#  'cet',
#  'excellent',
#  'ultraportable',
#  'bat',
#  'un',
#  'nouveau',
#  'record',
#  'd',
#  'endurance',
#  '5651.html',
#  '404',
#  'tests',
#  'on',
#  'a',
#  'teste',
#  'l',
#  'olympus',
#  'om',
#  'd',
#  'e',
#  'm10',
#  'mark',
#  'iii',
#  'l',
#  'hybride',
#  'compact',
#  'retrochic',
#  '5915.html',
#  'services',
#  'en',
#  'ligne',
#  'photoshop',
#  'com',
#  '120556',
#  'postele',
#  'forum',
#  'tests',
#  'test',
#  'miele',
#  'scout',
#  'rx1',
#  'un',
#  'aspirateur',
#  'robot',
#  'bien',
#  'equipe',
#  'pas',
#  'toujours',
#  'efficace',
#  '4939.html',
#  'actualites',
#  'le',
#  'top',
#  '10',
#  'des',
#  'smartphones',
#  '4g',
#  'a',
#  'moins',
#  'de',
#  '200',
#  'euros',
#  '1028395.html',
#  'tests',
#  'comparateur',
#  'huawei',
#  'honor',
#  '8',
#  'huawei',
#  'honor',
#  'view',
#  '10',
#  '29991',
#  '48883.html',
#  'telecharger',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'disque',
#  'dur',
#  'cdrom',
#  'dvd',
#  'fiches',
#  'avis',
#  '116150.html',
#  'forum',
#  'high',
#  'tech',
#  'LOGICIELS',
#  'Bureautique',
#  'transcription',
#  'logiciel',
#  'gratuit',
#  'sujet',
#  '359726',
#  '1.htm',
#  'mediaplayer',
#  'video',
#  'xz2',
#  'et',
#  'xz2',
#  'compact',
#  'enfin',
#  'du',
#  'renouveau',
#  'chez',
#  'sony',
#  '1040679.html',
#  'telecharger',
#  'tests',
#  'imprimantes',
#  'jet',
#  'd',
#  'encres',
#  'statiquesv6',
#  'telecharger',
#  'top',
#  'post',
#  'telechargement.html',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'sauvegarde',
#  'fiches',
#  '41899.html',
#  'telecharger',
#  'windows',
#  'Multimedia',
#  'scanner',
#  'ocr',
#  'accueil',
#  '2',
#  'telecharger',
#  'mac',
#  'Utilitaire',
#  'fiches',
#  '27507.html',
#  'tests',
#  'test',
#  'p8',
#  'lite',
#  '2017',
#  'un',
#  'smartphone',
#  'beau',
#  'performant',
#  'et',
#  'd',
#  'un',
#  'rapport',
#  'qualite',
#  'prix',
#  'imbattable',
#  '5642.html',
#  'actualites',
#  'jeu',
#  'concours',
#  'tentez',
#  'de',
#  'gagner',
#  '4',
#  'disques',
#  'durs',
#  'externes',
#  'toshiba',
#  'canvio',
#  'for',
#  'desktop',
#  '1372809.html',
#  'actualites',
#  'forum',
#  'high',
#  'tech',
#  'ARCHIVE',
#  'L',
#  'ORDINATEUR',
#  'INDIVIDUEL',
#  'Insolite',
#  'compilation',
#  'images',
#  'insolites',
#  'sujet',
#  '13599',
#  '1.htm',
#  'outils',
#  'telecharger',
#  'windows',
#  'Internet',
#  'internet',
#  'utlitaire',
#  'fiches',
#  'tele14537.html',
#  'services',
#  'en',
#  'ligne',
#  'beezik',
#  '117226',
#  'no_param',
#  'astuces',
#  'comment',
#  'installer',
#  'windows',
#  '10',
#  'sur',
#  'votre',
#  'pc',
#  'gratuitement',
#  '1358237.html',
#  'telecharger',
#  'windows',
#  'Utilitaire',
#  'optimiseurs',
#  'et',
#  'tests',
#  'fiches',
#  '124191.html',
#  'actualites',
#  'bon',
#  'plan',
#  'orange',
#  'casse',
#  'le',
#  'prix',
#  'du',
#  'samsung',
#  'galaxy',
#  's7',
#  '1364615.html',
#  'telecharger',
#  'windows',
#  'Loisirs',
#  'automobile',
#  'fiches',
#  'telecharger',
#  '51013.html',
#  'tests',
#  'test',
#  'nikon',
#  'coolpix',
#  'p610',
#  'un',
#  'bridge',
#  'efficace',
#  'puissant',
#  'et',
#  'pas',
#  'cher',
#  '5194.html',
#  'actualites',
#  'pourquoi',
#  'il',
#  'faut',
#  'se',
#  'mefier',
#  'de',
#  'skype',
#  'et',
#  'de',
#  'ses',
#  'programmes',
#  'd',
#  'installation',
#  '1377560.html',
#  'actualites',
#  'jeu',
#  'concours',
#  'tentez',
#  'de',
#  'gagner',
#  '4',
#  'disques',
#  'durs',
#  'externes',
#  'toshiba',
#  'canvio',
#  'for',
#  'desktop',
#  '1372809.html',
#  'recherche',
#  'recherche.php',
#  'actualites',
#  'actualites',
#  'mwc',
#  '2018',
#  'caterpillar',
#  'lance',
#  'le',
#  'plus',
#  'ambitieux',
#  'et',
#  'le',
#  'plus',
#  'cher',
#  'des',
#  ...]
